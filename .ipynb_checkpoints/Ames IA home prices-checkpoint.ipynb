# %% [markdown]
# # Predicting home prices in Ames, IA

# %% [markdown]
# The purpose of this notebook is for me to learn something about Python programming, how to process data using Python, and how to perform machine learning tasks in Python. It may perhaps also provide some decent predictions of house prices in Ames, IA.
#
# This data holds quite a bit of interest for me, because my wife and I are currently going through the process on both sides of the table - we've put our current house on the market, and we have a new house under contract.
#
# I'd also like to invite anyone who takes the time to read this to point out ways in which my methods or code could be better, as I'm still figuring all this out. Also, **this is a work in progress**, so it will have many updates.

# %% [markdown]
# ## 1 Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sb

# %% [markdown]
# ## 2 Read in the data

# %%
train = pd.read_csv("./Data/train.csv", header=0)
train.head(5)
test = pd.read_csv("./Data/test.csv", header=0)

# %% [markdown]
# ## 3 Data cleaning and exploration

# %% [markdown]
# Let's check to what extent we need to clean up the data before throwing a model at it. Let's also pick the features we are going to use, in order to cut down on the amount of cleaning we have to do - we can always expand it later.

# %% [markdown]
# ### 3.1 Missing values

# %% [markdown]
# It looks like several columns have a lot of missing values. From the data dictionary provided, it seems that this should be expected. These should be interpreted as the absence of a given feature rather than a missing value. However, we're going to have to do something with them, because scikit-learn doesn't like them. Scikit also doesn't want the alpha fields, which appear to be categorical in nature.

# %%
print ("Training set rows:", len(train))
print ("Test set rows:", len(test))
# Out:
# Training set rows: 1460
# Test set rows: 1459

# %%
train['SalePrice'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No missing sale prices either, so that's good.

# %% [markdown]
# ### 3.2 Data exploration

# %% [markdown]
# There are 81 columns of data and 1460 rows. We don't want to go too nuts with the number of features here, as there will not be enough houses in any one set of feature values to obtain stable predictions.
#
# Let's check out any missing values.

# %%
missing = len(train) - train.count()

# %%
missing.sort_values(ascending=False)[0:20]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %% [markdown]
# So most houses do not have a pool, and don't have junk like extra garages, tennis courts, or elevators. In addition most don't have an alley access and don't have a fence. I have two enormous dogs - a Saint Bernard and a Greater Swiss Mountain Dog mix, so a fence would be a must for me - but I feel like most people would take that into account as regards their own situation, and that it wouldn't influence the price that much, all other things being equal.
#
# All the garage information missing is for houses that didn't have a garage in the first place, and the same for the basement columns.

# %% [markdown]
# #### 3.2.1 Neighborhoods

# %% [markdown]
# I am not from Ames, Iowa, so I don't know what meaning the names of the neighborhoods have. Let's see if we can get some from the training data.

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.75, 7.0)
ax = plt.axes()
plot1 = sb.boxplot(data=train, x='Neighborhood', y='SalePrice')
ax.set_title("Price distribution by neighborhood")
sb.despine(offset=10, trim=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Let's bucket these into "low", "middle", and "high" neighborhoods. This is a subjective assignment based on my lying eyes, and so it could fairly be argued about.

# %%
def transform_nb(x):
    if x in ("NoRidge", "NridgHt", "StoneBr","Timber","Veenker"):
        return "Hi"
    elif x in ("Mitchel","OldTown","BrkSide","Sawyer","NAmes","IDOTRR","MeadowV","Edwards","NPkVill","BrDale","Blueste"):
        return "Low"
    else:
        return "Mid"

# %%
train["NbdClass"] = train["Neighborhood"].apply(transform_nb)

# %%
set(train["NbdClass"])
# Out:
# {'Hi', 'Low', 'Mid'}

# %%
train["NbdClass"].value_counts()
# Out:
# Low    700
# Mid    568
# Hi     192
# Name: NbdClass, dtype: int64

# %% [markdown]
# Let's redo the box plot by these three classes and see how it turns out:

# %%
ax = plt.axes()
plot2 = sb.boxplot(data=train, x='NbdClass', y='SalePrice')
ax.set_title("Price distribution by neighborhood class")
sb.despine(offset=10, trim=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# So that knocks a lot of categories down to three, in what I feel is a reasonable way. However, it does mean that the price of the "high" class neighborhoods may be harder to predict.
#
# What else should we look at? They say people can get carried away looking at kitchens and bathrooms. There is a feature for kitchen quality, but none for bathroom quality, and condition of these isn't addressed at all. It's probably fair to assume that a large portion of the overall condition assessment covers the kitchen and bathrooms.

# %%
ax = plt.axes()
plot3 = sb.boxplot(data=train, x='KitchenQual', y='SalePrice')
ax.set_title("Price distribution by kitchen quality")
sb.despine(offset=10, trim=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# That's more or less what I would have expected to see, although it looks like there's not much difference between "average" and "fair", and there are no "poor" kitchens. Let's check out overall quality.

# %%
ax = plt.axes()
plot4 = sb.boxplot(data=train, x='OverallQual', y='SalePrice')
ax.set_title("Price distribution by overall house quality")
sb.despine(offset=10, trim=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It's almost like they planned it that way. That's definitely going to help as a predictor. Now, it might be reasonable to assume that if a person tours a house and says "Wow, the kitchen sucks", then they are going to think less of the house overall. It's therefore likely that these are collinear to some extent. Correlation can help identify these. First, I'll separate the categorical from the numeric variables, as others here have done. There are a few fields that are numeric data types but really are categorical - I'll leave these as numeric.

# %%
to_cat = ['MSSubClass', 'MSZoning', 'Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope',
         'Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle',
         'RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond',
          'BsmtExposure','BsmtFinType1','BsmtFinType2','Heating', 'HeatingQC','CentralAir','Electrical','KitchenQual',
          'Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence',
          'MiscFeature','SaleType','SaleCondition','NbdClass']

# %%
to_num = ['LotFrontage','LotArea','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
          'TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','Bedroom',
         'Kitchen','TotRmsAbvGrd','Fireplaces','GarageYrBlt','GarageCars','GarageArea','WoodDeckSF','OpenPorchSF',
         'EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold','LowQualFinSF','OverallQual',
         'OverallCond']

# %%
len(to_cat)+len(to_num)
# Out:
# 80

# %% [markdown]
# That last bit was just a check to make sure I got them all. The only ones left are the house ID and the sale price, making the full 82 columns. We'll convert the first batch of columns into Pandas categories.

# %%
def convertCat(x):
    return x.astype('category')

# %%
for column in to_cat:
    train[column] = convertCat(train[column])

# %%
# Order categories - this might not make any difference,
# I'm figuring all this out for the first time
train['ExterQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
train['ExterCond'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
train['BsmtQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
train['BsmtCond'].cat.reorder_categories(['Gd','TA','Fa','Po'])
train['BsmtExposure'].cat.reorder_categories(['Gd','Av','Mn','No'])
train['HeatingQC'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
train['KitchenQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
train['FireplaceQu'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
train['GarageQual'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
train['GarageCond'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
train['PoolQC'].cat.reorder_categories(['Ex','Gd','Fa'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#        ...
# 1430    NaN
# 1431    NaN
# 1432    NaN
# 1433    NaN
# 1434    NaN
# 1435    NaN
# 1436    NaN
# 1437    NaN
# 1438    NaN
# 1439    NaN
# 1440    NaN
# 1441    NaN
# 1442    NaN
# 1443    NaN
# 1444    NaN
# 1445    NaN
# 1446    NaN
# 1447    NaN
# 1448    NaN
# 1449    NaN
# 1450    NaN
# 1451    NaN
# 1452    NaN
# 1453    NaN
# 1454    NaN
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# dtype: category
# Categories (3, object): [Ex, Gd, Fa]

# %% [markdown]
# ### 3.3 A deeper dive
#
# Now, let's recreate the graphs found in [this kernel](https://www.kaggle.com/notaapple/house-prices-advanced-regression-techniques/detailed-exploratory-data-analysis-using-r/comments), which was done using R. But first: a helper function, because I am lazy.

# %%
def doPlots(x, data, ii, fun):
    fig, axes = plt.subplots(len(ii) // 2, ncols = 2)
    fig.tight_layout()
    for i in range(len(ii)):
        fun(x=x[ii[i]], data=data, ax=axes[i // 2, i % 2], color='dimgrey')
    plt.show()

# %%
doPlots(to_cat, train, range(0,4),sb.countplot)

# %% [markdown]
# From these we can make the following observations:
#
# * Most (over 900 of the 1460) have been built since 1946.
# * The lion's share are zoned for residential, meaning this variable won't help too much.
# * Almost all (if not literally all) are on paved streets.
# * There are less than 100 houses with an alley (graphs ignore NaNs - if you can tell me how to force their inclusion I'd appreciate it).
#
# On we go:

# %%
doPlots(to_cat, train, range(4,14),sb.countplot)

# %% [markdown]
# More observations:
#
# * Almost all houses in the data are on regular (I assume rectangular) or "slightly irregular" lots - whatever that may mean.
# * Almost all houses are built on level ground. (We have rather a lot of it out here.)
# * Almost all houses are on a "gentle" slope.
# * A great many of the houses are in "normal" conditions; i.e. not on a major artery or feeder street, and not near railroad tracks or near parks. Either the creator of this dataset must have been studiously avoiding such confounding effects, or Ames, Iowa has the most Type A city planners on the face of the Earth.
# * Most of the houses are single-family homes with one or two stories.
#
# Still with me? Fantastic. So far, I haven't seen too many things in this grand tour that would give me a ton of predicting power, but we'll see.

# %%
doPlots(to_cat, train, range(14,22),sb.countplot)

# %% [markdown]
# Some more observations:
#
# * A wide range of siding materials is represented. Again I wonder if this is coincidental or intentional.
# * Quite a number of cinder block basements, which I would expect to be of generally worse quality overall.
# * Pretty fair distribution of basement finish qualities, which we'll see in the next set of graphs.
#
# If you know how to fix the spacing so that the x-axis tick labels are always fully visible, let me know.

# %%
doPlots(to_cat, train, range(23,31),sb.countplot)

# %% [markdown]
# More plots:

# %%
doPlots(to_cat, train, range(32,40),sb.countplot)

# %% [markdown]
# Observations:
# * Heating and AC are both needed in this part of the country. I live fairly close to Ames in a cosmic sense, and where I live we have had 115F days and -10F days in the same year. Unsurprisingly, it looks like most houses in Ames have both.
# * A decent fireplace is nice too.
# * Most houses are labelled as 'Typical Functionality' as opposed to 'deductions', whatever those may mean. Possibly things that would be dinged in a formal inspection?
# * Quite a few finished or partially finished garages.
# * Very few houses in the training sample have a pool.

# %%
doPlots(to_cat, train, range(40,44),sb.countplot)

# %% [markdown]
# * Most houses in the sample don't have a fence either.
# * Most of these houses were purchased in the traditional way.

# %% [markdown]
# ### 3.4 Correlation
# Now to reproduce the quite fetching pairwise-correlation graph in the kernel linked above. Fortunately when I logged into Kaggle today one of the first things I saw was [this guy's graph](https://www.kaggle.com/arthurtok/d/deepmatrix/imdb-5000-movie-dataset/principal-component-analysis-with-kmeans-visuals) that does exactly what I want. Good artists create; great artists steal. In my version, blue is negative correlation, and red is positive. I don't even bother with any cell with a correlation inside of $(-0.4, 0.4)$.

# %%
mask = (train.select_dtypes(['float64','int64']).corr() < 0.4) & (train.select_dtypes(['float64','int64']).corr() > -0.4)

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
plt.title('Pearson Correlation of Numeric Variables')
# Draw the heatmap using seaborn
sb.heatmap(train.select_dtypes(['float64','int64']).corr(),linewidths=0.35,vmax=1.0, square=True, cmap="coolwarm", mask=mask)

# %% [markdown]
# Here, we see the numeric variables that have stronger positive correlations with sale price.
#
# * Overall quality
# * Year built
# * Year remodeled
# * Amount of masonry veneer (?!?)
# * Total basement square footage
# * Living area square feet above grade
# * Number of full bathrooms
# * Number of rooms above grade (should be collinear with the square feet above grade)
# * Number of fireplaces
# * Year of garage construction
# * Garage square feet

# %% [markdown]
# ## 4 Feature engineering
# Next, we're going to mash some columns together to make some features to model against. First, how about 'years since last remodel'?

# %%
train['LastRmdlYr'] = train['YearRemodAdd'] - train['YearBuilt']

# %% [markdown]
# Next, we'll mash all the square feet columns into a single column for finished square feet:

# %%
train['TotalSqFt'] = train['TotalBsmtSF'] - train['BsmtUnfSF'] + train['GrLivArea']

# %% [markdown]
# Now for the features list. We have some fancy techniques so we may as well throw everything and the kitchen sink at it.

# %%
features = ['OverallQual','YearBuilt','LastRmdlYr','MasVnrArea','TotalSqFt','FullBath','Fireplaces',
           'GarageYrBlt','GarageCars','NbdClass','HouseStyle','Alley','LotShape','LotConfig','Exterior1st',
           'Exterior2nd','ExterQual','ExterCond','Foundation','BsmtExposure','BsmtFinType1','HeatingQC','CentralAir',
           'FireplaceQu','GarageType','GarageFinish']
target = 'SalePrice'

# %% [markdown]
# ## 5 Prepare test set
# Everything we did to the training set, we must now do to the test set.

# %%
test["NbdClass"] = test["Neighborhood"].apply(transform_nb)

# %%
for column in to_cat:
    test[column] = convertCat(test[column])

# %%
# Order categories - this might not make any difference,
# I'm figuring all this out for the first time
test['ExterQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
test['ExterCond'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
test['BsmtQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
test['BsmtCond'].cat.reorder_categories(['Gd','TA','Fa','Po'])
test['BsmtExposure'].cat.reorder_categories(['Gd','Av','Mn','No'])
test['HeatingQC'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
test['KitchenQual'].cat.reorder_categories(['Ex','Gd','TA','Fa'])
test['FireplaceQu'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
test['GarageQual'].cat.reorder_categories(['Gd','TA','Fa','Po'])
test['GarageCond'].cat.reorder_categories(['Ex','Gd','TA','Fa','Po'])
test['PoolQC'].cat.reorder_categories(['Ex','Gd'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#        ...
# 1429    NaN
# 1430    NaN
# 1431    NaN
# 1432    NaN
# 1433    NaN
# 1434    NaN
# 1435    NaN
# 1436    NaN
# 1437    NaN
# 1438    NaN
# 1439    NaN
# 1440    NaN
# 1441    NaN
# 1442    NaN
# 1443    NaN
# 1444    NaN
# 1445    NaN
# 1446    NaN
# 1447    NaN
# 1448    NaN
# 1449    NaN
# 1450    NaN
# 1451    NaN
# 1452    NaN
# 1453    NaN
# 1454    NaN
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# dtype: category
# Categories (2, object): [Ex, Gd]

# %%
test['LastRmdlYr'] = test['YearRemodAdd'] - test['YearBuilt']
test['TotalSqFt'] = test['TotalBsmtSF'] - test['BsmtUnfSF'] + train['GrLivArea']

# %% [markdown]
# Now we need to convert everything into a form that our models can use.

# %%
trainX = pd.get_dummies(train[features])

# %%
testX = pd.get_dummies(test[features])

# %%
trainY = train['SalePrice'].values

# %% [markdown]
# ## 6 Modeling - Ridge regression
